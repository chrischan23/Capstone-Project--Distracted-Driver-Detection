# %% [markdown]
# # Capstone Project - Distracted Driver Detection -Resnet 50

# %% [markdown]
# # Import Libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns 
import os
import cv2
import itertools
import math

from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, RepeatedStratifiedKFold, cross_val_score
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, precision_score, recall_score, f1_score
from sklearn import metrics
from sklearn.preprocessing import StandardScaler

from keras.utils import np_utils

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from tensorflow.keras import optimizers

from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.layers import Input
#from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.models import Model
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input

import random

# %matplotlib inline

# %% [markdown]
# # Google Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Import Dataset

# %%
train = pd.read_csv("/content/drive/MyDrive/capstone/datasets/driver_imgs_list.csv")
print('Number of samples in trainset : {}'.format(train.shape[0]))
print('Number of classes to predict : {}'.format(len((train.classname).unique())))
train.head()
# Out:
# Number of samples in trainset : 22424
# Number of classes to predict : 10
#   subject classname            img
# 0    p002        c0  img_44733.jpg
# 1    p002        c0  img_72999.jpg
# 2    p002        c0  img_25094.jpg
# 3    p002        c0  img_69092.jpg
# 4    p002        c0  img_92629.jpg

# %% [markdown]
# # Split data set by driver id

# %%
def custom_train_test_split_images(train_subjects, 
                                   test_subjects,
                                   val_subjects,
                                   dataDir = "/content/drive/MyDrive/capstone/assets/imgs/train", 
                                   labels= ['c0', 'c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'c9'],
                                   train=train,
                                   shuffle=True):
    
    x_train, x_val, x_test, y_train, y_val, y_test = [],[],[],[],[],[]
    
    for label in labels:
        path = os.path.join(dataDir, label) #path to labels directory
        class_num = labels.index(label)
        
        for img in os.listdir(path):
            
            img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE) #read image, convert to grayscale
            new_array = cv2.resize(img_array, (224, 224)) #resize
            
            current_subject = train.loc[train['img'] == img, 'subject'].item() #locate all images relating to a driver
            
            if current_subject in train_subjects:
                x_train.append(new_array)
                y_train.append(class_num)
                
            elif current_subject in test_subjects:
                x_test.append(new_array)
                y_test.append(class_num)
                
            elif current_subject in val_subjects:
                x_val.append(new_array)
                y_val.append(class_num)

    if shuffle: #shuffle data
        train_tmp, val_tmp, test_tmp = list(zip(x_train, y_train)), list(zip(x_val, y_val)), list(zip(x_test, y_test))
        random.shuffle(train_tmp)
        random.shuffle(val_tmp)
        random.shuffle(test_tmp)
        
        x_train, y_train = list(zip(*train_tmp))
        x_val, y_val = list(zip(*val_tmp))
        x_test, y_test = list(zip(*test_tmp))

    return x_train, x_val, x_test, y_train, y_val, y_test

# %%
#code was run on jupyter notebook

# drivers = train.groupby('subject')
# unique_drivers = drivers.groups.keys()

# train_ratio = .5
# test_ratio = .25
# train_subject_len = int(np.floor(len(unique_drivers) * train_ratio))
# test_subject_len = int(np.floor(len(unique_drivers) * (train_ratio + test_ratio)))


# train_subjects = list(unique_drivers)[:train_subject_len]
# test_subjects = list(unique_drivers)[train_subject_len:test_subject_len]
# val_subjects = list(unique_drivers)[test_subject_len:]

# print('train subjects: ', train_subjects)
# print('test subjects: ', test_subjects)
# print('val subjects: ', val_subjects)


# X_train, X_val, X_test, y_train, y_val, y_test = custom_train_test_split_images(train_subjects=train_subjects, 
#                                         test_subjects=test_subjects, 
#                                         val_subjects=val_subjects)

# %% [markdown]
# # Preprocess data

# %%
#code was run on jupyter notebook

# def preprocess(x_train, x_val, x_test, y_train, y_val, y_test):
#     x_train = np.array(x_train, dtype=np.float32)
#     x_val = np.array(x_val, dtype=np.float32)
#     x_test = np.array(x_test, dtype=np.float32)
    
#     x_train_flat = x_train.reshape(x_train.shape[0],-1)
#     x_val_flat = x_val.reshape(x_val.shape[0],-1)
#     x_test_flat = x_test.reshape(x_test.shape[0],-1)
    
#     ss = StandardScaler()
#     x_train_flat = ss.fit_transform(x_train_flat)
#     x_train_final = x_train_flat.reshape(x_train.shape[0],x_train.shape[1],x_train.shape[2],-1)
    
#     x_val_flat = ss.transform(x_val_flat)
#     x_val_final = x_val_flat.reshape(x_val.shape[0],x_val.shape[1],x_val.shape[2],-1)
    
#     x_test_flat = ss.transform(x_test_flat)
#     x_test_final = x_test_flat.reshape(x_test.shape[0],x_test.shape[1],x_test.shape[2],-1)
    
#     y_train, y_val, y_test = np_utils.to_categorical(y_train, 10), np_utils.to_categorical(y_val, 10), np_utils.to_categorical(y_test, 10)
    
#     return x_train_final, x_val_final, x_test_final, y_train, y_val, y_test

# X_train, X_val, X_test, y_train, y_val, y_test = preprocess(X_train, X_val, X_test, y_train, y_val, y_test)

# %% [markdown]
# # Load Variables from Jupyter Notebook

# %%
def load_arr(filename):
    with open(filename, 'rb') as f:
        return np.load(f)

X_train = load_arr('/content/drive/MyDrive/capstone/code/pretrained_models/new_X_train.npy')
X_val = load_arr('/content/drive/MyDrive/capstone/code/pretrained_models/new_X_val.npy')
X_test = load_arr('/content/drive/MyDrive/capstone/code/pretrained_models/new_X_test.npy')
y_train = load_arr('/content/drive/MyDrive/capstone/code/pretrained_models/new_y_train.npy')
y_val = load_arr('/content/drive/MyDrive/capstone/code/pretrained_models/new_y_val.npy')
y_test = load_arr('/content/drive/MyDrive/capstone/code/pretrained_models/new_y_test.npy')

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (11964, 224, 224, 3)
# (11964, 10)

# %% [markdown]
# # Resnet50

# %%
resnet50_input = Input(shape = (224, 224, 3), name = 'Image_input')
model_resnet50 = ResNet50(weights= 'imagenet', include_top=False, input_shape= (224,224,3))
output_resnet50 = model_resnet50(resnet50_input)


#Add the fully-connected layers 
x = Flatten(name='flatten')(output_resnet50)
x = Dense(10, activation='softmax', name='predictions')(x)

model = Model(resnet50_input, x)

def step_decay(epoch):
    initial_lrate = 0.001
    drop = 0.5
    epochs_drop = 10.0
    lrate = initial_lrate * math.pow(drop,  
        math.floor((1+epoch)/epochs_drop))
    return lrate
lrate = LearningRateScheduler(step_decay)


# Compile CNN model
sgd = optimizers.SGD(lr = 0.001)
model.compile(loss='categorical_crossentropy',optimizer = sgd,metrics=['accuracy'])

#callbacks
early_stop = EarlyStopping(monitor = 'accuracy', min_delta = 0, patience = 7, verbose = 1, mode='auto')
checkpointer = ModelCheckpoint('resnet_weights_aug_alltrained_sgd2_setval.hdf5', verbose=1, save_best_only=True)

# %%
datagen = ImageDataGenerator(
    height_shift_range=0.5,
    width_shift_range = 0.5,
    zoom_range = 0.5,
    rotation_range=30
        )

data_generator = datagen.flow(X_train, y_train, batch_size = 64)

# Fits the model on batches with real-time data augmentation:
history = model.fit(data_generator,
                        steps_per_epoch = len(X_train) / 64,
                        callbacks=[checkpointer, early_stop, lrate],
                        epochs = 30, 
                        verbose = 1, 
                        validation_data = (X_test, y_test))
# Out:
# Epoch 1/30
# 186/186 [==============================] - 138s 715ms/step - loss: 3.4610 - accuracy: 0.1929 - val_loss: 4.5231 - val_accuracy: 0.1398
#
# Epoch 00001: val_loss improved from inf to 4.52307, saving model to resnet_weights_aug_alltrained_sgd2_setval.hdf5
# Epoch 2/30
# 186/186 [==============================] - 130s 696ms/step - loss: 1.8557 - accuracy: 0.4739 - val_loss: 4.7452 - val_accuracy: 0.1793
#
# Epoch 00002: val_loss did not improve from 4.52307
# Epoch 3/30
# 186/186 [==============================] - 129s 689ms/step - loss: 1.2261 - accuracy: 0.6312 - val_loss: 3.8815 - val_accuracy: 0.2777
#
# Epoch 00003: val_loss improved from 4.52307 to 3.88154, saving model to resnet_weights_aug_alltrained_sgd2_setval.hdf5
# Epoch 4/30
# 186/186 [==============================] - 127s 679ms/step - loss: 0.9738 - accuracy: 0.7058 - val_loss: 3.2925 - val_accuracy: 0.4924
#
# Epoch 00004: val_loss improved from 3.88154 to 3.29253, saving model to resnet_weights_aug_alltrained_sgd2_setval.hdf5
# Epoch 5/30
# 186/186 [==============================] - 127s 679ms/step - loss: 0.8083 - accuracy: 0.7473 - val_loss: 2.5123 - val_accuracy: 0.5867
#
# Epoch 00005: val_loss improved from 3.29253 to 2.51228, saving model to resnet_weights_aug_alltrained_sgd2_setval.hdf5
# Epoch 6/30
# 186/186 [==============================] - 126s 675ms/step - loss: 0.7355 - accuracy: 0.7698 - val_loss: 1.5599 - val_accuracy: 0.6892
#
# Epoch 00006: val_loss improved from 2.51228 to 1.55987, saving model to resnet_weights_aug_alltrained_sgd2_setval.hdf5
# Epoch 7/30
# 186/186 [==============================] - 127s 676ms/step - loss: 0.6466 - accuracy: 0.7968 - val_loss: 1.4876 - val_accuracy: 0.6827
#
# Epoch 00007: val_loss improved from 1.55987 to 1.48760, saving model to resnet_weights_aug_alltrained_sgd2_setval.hdf5
# Epoch 8/30
# 186/186 [==============================] - 127s 679ms/step - loss: 0.6035 - accuracy: 0.8129 - val_loss: 1.5275 - val_accuracy: 0.6890
#
# Epoch 00008: val_loss did not improve from 1.48760
# Epoch 9/30
# 186/186 [==============================] - 129s 690ms/step - loss: 0.5513 - accuracy: 0.8206 - val_loss: 1.4574 - val_accuracy: 0.6875
#
# Epoch 00009: val_loss improved from 1.48760 to 1.45738, saving model to resnet_weights_aug_alltrained_sgd2_setval.hdf5
# Epoch 10/30
# 186/186 [==============================] - 129s 689ms/step - loss: 0.5287 - accuracy: 0.8279 - val_loss: 1.4019 - val_accuracy: 0.6819
#
# Epoch 00010: val_loss improved from 1.45738 to 1.40194, saving model to resnet_weights_aug_alltrained_sgd2_setval.hdf5
# Epoch 11/30
# 186/186 [==============================] - 128s 684ms/step - loss: 0.4891 - accuracy: 0.8419 - val_loss: 1.3954 - val_accuracy: 0.6954
#
# Epoch 00011: val_loss improved from 1.40194 to 1.39545, saving model to resnet_weights_aug_alltrained_sgd2_setval.hdf5
# Epoch 12/30
# 186/186 [==============================] - 128s 685ms/step - loss: 0.4556 - accuracy: 0.8495 - val_loss: 1.4210 - val_accuracy: 0.6922
#
# Epoch 00012: val_loss did not improve from 1.39545
# Epoch 13/30
# 186/186 [==============================] - 130s 695ms/step - loss: 0.4507 - accuracy: 0.8466 - val_loss: 1.4552 - val_accuracy: 0.6918
#
# Epoch 00013: val_loss did not improve from 1.39545
# Epoch 14/30
# 186/186 [==============================] - 130s 696ms/step - loss: 0.4190 - accuracy: 0.8618 - val_loss: 1.3699 - val_accuracy: 0.7046
#
# Epoch 00014: val_loss improved from 1.39545 to 1.36989, saving model to resnet_weights_aug_alltrained_sgd2_setval.hdf5
# Epoch 15/30
# 186/186 [==============================] - 128s 686ms/step - loss: 0.4285 - accuracy: 0.8608 - val_loss: 1.2572 - val_accuracy: 0.7247
#
# Epoch 00015: val_loss improved from 1.36989 to 1.25720, saving model to resnet_weights_aug_alltrained_sgd2_setval.hdf5
# Epoch 16/30
# 186/186 [==============================] - 129s 691ms/step - loss: 0.4082 - accuracy: 0.8641 - val_loss: 1.3401 - val_accuracy: 0.7177
#
# Epoch 00016: val_loss did not improve from 1.25720
# Epoch 17/30
# 186/186 [==============================] - 128s 684ms/step - loss: 0.3857 - accuracy: 0.8719 - val_loss: 1.2876 - val_accuracy: 0.7104
#
# Epoch 00017: val_loss did not improve from 1.25720
# Epoch 18/30
# 186/186 [==============================] - 128s 682ms/step - loss: 0.3892 - accuracy: 0.8698 - val_loss: 1.4278 - val_accuracy: 0.7026
#
# Epoch 00018: val_loss did not improve from 1.25720
# Epoch 19/30
# 186/186 [==============================] - 126s 675ms/step - loss: 0.3849 - accuracy: 0.8702 - val_loss: 1.2377 - val_accuracy: 0.7293
#
# Epoch 00019: val_loss improved from 1.25720 to 1.23769, saving model to resnet_weights_aug_alltrained_sgd2_setval.hdf5
# Epoch 20/30
# 186/186 [==============================] - 126s 674ms/step - loss: 0.3758 - accuracy: 0.8706 - val_loss: 1.2740 - val_accuracy: 0.7227
#
# Epoch 00020: val_loss did not improve from 1.23769
# Epoch 21/30
# 186/186 [==============================] - 127s 677ms/step - loss: 0.3686 - accuracy: 0.8748 - val_loss: 1.1828 - val_accuracy: 0.7380
#
# Epoch 00021: val_loss improved from 1.23769 to 1.18284, saving model to resnet_weights_aug_alltrained_sgd2_setval.hdf5
# Epoch 22/30
# 186/186 [==============================] - 126s 671ms/step - loss: 0.3405 - accuracy: 0.8869 - val_loss: 1.2540 - val_accuracy: 0.7249
#
# Epoch 00022: val_loss did not improve from 1.18284
# Epoch 23/30
# 186/186 [==============================] - 127s 678ms/step - loss: 0.3528 - accuracy: 0.8842 - val_loss: 1.2250 - val_accuracy: 0.7227
#
# Epoch 00023: val_loss did not improve from 1.18284
# Epoch 24/30
# 186/186 [==============================] - 128s 685ms/step - loss: 0.3253 - accuracy: 0.8901 - val_loss: 1.2126 - val_accuracy: 0.7317
#
# Epoch 00024: val_loss did not improve from 1.18284
# Epoch 25/30
# 186/186 [==============================] - 129s 692ms/step - loss: 0.3395 - accuracy: 0.8843 - val_loss: 1.2213 - val_accuracy: 0.7317
#
# Epoch 00025: val_loss did not improve from 1.18284
# Epoch 26/30
# 186/186 [==============================] - 130s 695ms/step - loss: 0.3446 - accuracy: 0.8845 - val_loss: 1.2790 - val_accuracy: 0.7235
#
# Epoch 00026: val_loss did not improve from 1.18284
# Epoch 27/30
# 186/186 [==============================] - 127s 676ms/step - loss: 0.3151 - accuracy: 0.8932 - val_loss: 1.2701 - val_accuracy: 0.7217
#
# Epoch 00027: val_loss did not improve from 1.18284
# Epoch 28/30
# 186/186 [==============================] - 127s 681ms/step - loss: 0.3177 - accuracy: 0.8949 - val_loss: 1.2751 - val_accuracy: 0.7235
#
# Epoch 00028: val_loss did not improve from 1.18284
# Epoch 29/30
# 186/186 [==============================] - 129s 687ms/step - loss: 0.3317 - accuracy: 0.8887 - val_loss: 1.3258 - val_accuracy: 0.7169
#
# Epoch 00029: val_loss did not improve from 1.18284
# Epoch 30/30
# 186/186 [==============================] - 128s 684ms/step - loss: 0.3392 - accuracy: 0.8850 - val_loss: 1.2557 - val_accuracy: 0.7253
#
# Epoch 00030: val_loss did not improve from 1.18284

# %%
# resnet50_input = Input(shape = (224, 224, 3), name = 'Image_input')
# model_resnet50 = ResNet50(weights= 'imagenet', include_top=False, input_shape= (224,224,3))

# for layer in model_resnet50.layers:
#     layer.trainable = False #freeze weights
    
# last = model_resnet50.output
# x = Flatten()(last)
# x = Dense(512, activation='relu')(x)
# preds = Dense(10, activation='softmax')(x)
# model = Model(model_resnet50.input, preds)

# sgd = optimizers.SGD(lr = 0.001)
# model.compile(loss='categorical_crossentropy',optimizer = sgd,metrics=['accuracy'])


# early_stop = EarlyStopping(monitor = 'val_loss', min_delta = 0, patience = 5, verbose = 1, mode='auto')
# checkpointer = ModelCheckpoint('resnet_weights_aug_alltrained_sgd2_setval.hdf5', verbose=1, save_best_only=True)

# history = model.fit(X_train,
#                     y_train,
#                     batch_size=256,
#                     validation_data=(X_test, y_test),
#                     epochs=25,
#                     verbose=1,
#                     callbacks = [checkpointer, early_stop])

# %%
model.summary()
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Image_input (InputLayer)     [(None, 224, 224, 3)]     0
# _________________________________________________________________
# resnet50 (Functional)        (None, 7, 7, 2048)        23587712
# _________________________________________________________________
# flatten (Flatten)            (None, 100352)            0
# _________________________________________________________________
# predictions (Dense)          (None, 10)                1003530
# =================================================================
# Total params: 24,591,242
# Trainable params: 24,538,122
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
# Evaluate model on test data.
resnet_test_score = model.evaluate(X_test, y_test, verbose=1)

restnet_test_labels = model.metrics_names

print(f'Restnet50_test {restnet_test_labels[0]}  : {resnet_test_score[0]}')
print(f'Restnet50_test {restnet_test_labels[1]}   : {resnet_test_score[1]}')
# Out:
# 157/157 [==============================] - 6s 36ms/step - loss: 1.2557 - accuracy: 0.7253
# Restnet50_test loss  : 1.2556756734848022
# Restnet50_test accuracy   : 0.7252988219261169

# %%
# Check out our train loss and test loss over epochs.
train_loss_1 = history.history['loss']
test_loss_1 = history.history['val_loss']

# Set figure size.
plt.figure(figsize=(12, 8))

# Generate line plot of training, testing loss over epochs.
plt.plot(train_loss_1, label='Training Loss', color='#185fad')
plt.plot(test_loss_1, label='Testing Loss', color='orange')

# Set title
plt.title('CNN-1: Training and Testing Loss by Epoch', fontsize = 25)
plt.xlabel('Epoch', fontsize = 18)
plt.ylabel('Categorical Crossentropy', fontsize = 18)

plt.legend(fontsize = 18);

# %%
# Check out our train acc and test acc over epochs.
train_acc_1 = history.history['accuracy']
test_acc_1 = history.history['val_accuracy']

# Set figure size.
plt.figure(figsize=(12, 8))

# Generate line plot of training, testing loss over epochs.
plt.plot(train_acc_1, label='Training Accuracy', color='#185fad')
plt.plot(test_acc_1, label='Testing Accuracy', color='orange')

# Set title
plt.title('CNN-1:Training and Testing Accuracy by Epoch', fontsize = 25)
plt.xlabel('Epoch', fontsize = 18)
plt.ylabel('Categorical Crossentropy', fontsize = 18)

plt.legend(fontsize = 18);

# %%
classes = {"c0": "safe driving", 
           "c1": "texting - right", 
           "c2": "talking on the phone - right", 
           "c3": "texting - left",
           "c4": "talking on the phone - left", 
           "c5": "operating the radio", 
           "c6": "drinking", 
           "c7": "reaching behind",
           "c8": "hair and makeup", 
           "c9": "talking to passenger"}

# %%
def show_confusion_matrix(validations, predictions):

    matrix = metrics.confusion_matrix(validations, predictions)
    plt.figure(figsize=(10, 10))
    sns.heatmap(matrix,
                cmap='coolwarm',
                linecolor='white',
                linewidths=1,
                xticklabels=classes,
                yticklabels=classes,
                annot=True,
                fmt='d')
    plt.title('Confusion Matrix')
    plt.ylabel('True Label', rotation=90)
    plt.xlabel('Predicted Label')
    plt.yticks(rotation=45)
    plt.show()

y_pred = model.predict(X_test)
# Take the class with the highest probability from the test predictions
max_y_pred = np.argmax(y_pred, axis=1)
max_y_test = np.argmax(y_test, axis=1)

show_confusion_matrix(max_y_test, max_y_pred)

print(classification_report(max_y_test, max_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.52      0.61       616
#            1       0.95      0.76      0.85       448
#            2       0.76      0.82      0.79       493
#            3       0.77      0.99      0.87       527
#            4       0.80      0.76      0.78       502
#            5       0.75      0.67      0.71       525
#            6       0.92      0.51      0.66       525
#            7       0.69      0.98      0.81       455
#            8       0.49      0.75      0.59       425
#            9       0.59      0.57      0.58       504
#
#     accuracy                           0.73      5020
#    macro avg       0.75      0.73      0.72      5020
# weighted avg       0.75      0.73      0.72      5020

# %% [markdown]
# # Predicted Images

# %%
tags = { "C0": "safe driving",
"C1": "texting - right",
"C2": "talking on the phone - right",
"C3": "texting - left",
"C4": "talking on the phone - left",
"C5": "operating the radio",
"C6": "drinking",
"C7": "reaching behind",
"C8": "hair and makeup",
"C9": "talking to passenger" }

# %%
# labels is the image array
i = 0
fig, ax = plt.subplots(10, 1, figsize = (50,50))

for i in range(10):
    ax[i].imshow(X_test[i].squeeze())
    preds_class = 'C'+str(np.where(y_pred[i] == np.amax(y_pred[i]))[0][0])
    ax[i].set_title(tags[preds_class])
    plt.show
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
